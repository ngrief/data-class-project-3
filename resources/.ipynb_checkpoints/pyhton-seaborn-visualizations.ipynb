# %%
import pandas as pd
from pathlib import Path

# %%
csv_file = Path("migration_population.csv")

# %%
data_df = pd.read_csv(csv_file)
data_df
# Out:
#           country  year   population  pop_density  net_migration  \
# 0      Arab World  2018  419790588.0    37.372365            NaN
# 1      Arab World  2017  411898965.0    36.669804     -1408824.0
# 2      Arab World  2016  404024433.0    35.968764            NaN
# 3      Arab World  2015  396028278.0    35.256897            NaN
# 4      Arab World  2014  387907748.0    34.533978            NaN
# ...           ...   ...          ...          ...            ...
# 15571    Zimbabwe  1964    4322861.0    11.174515            NaN
# 15572    Zimbabwe  1963    4178726.0    10.801928            NaN
# 15573    Zimbabwe  1962    4039201.0    10.441259       -15009.0
# 15574    Zimbabwe  1961    3905034.0    10.094440            NaN
# 15575    Zimbabwe  1960    3776681.0          NaN            NaN
#
#        migration_perc iso3c iso2c               region  \
# 0                 NaN   ARB    1A           Aggregates
# 1           -0.003420   ARB    1A           Aggregates
# ...

# %%
data_df.columns.tolist()
# Out:
# ['country',
#  'year',
#  'population',
#  'pop_density',
#  'net_migration',
#  'migration_perc',
#  'iso3c',
#  'iso2c',
#  'region',
#  'adminregion',
#  'incomeLevel',
#  'lendingType',
#  'capitalCity',
#  'longitude',
#  'latitude']

# %%
pd.set_option("display.max_columns", None)
data_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15576 entries, 0 to 15575
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country         15576 non-null  object
#  1   year            15576 non-null  int64
#  2   population      15409 non-null  float64
#  3   pop_density     14830 non-null  float64
#  4   net_migration   2868 non-null   float64
#  5   migration_perc  2865 non-null   float64
#  6   iso3c           15458 non-null  object
#  7   iso2c           15399 non-null  object
#  8   region          15458 non-null  object
#  9   adminregion     8142 non-null   object
#  10  incomeLevel     15458 non-null  object
#  11  lendingType     15458 non-null  object
#  12  capitalCity     12449 non-null  object
#  13  longitude       12449 non-null  float64
#  14  latitude        12449 non-null  float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 1.8+ MB

# %%
columns_to_remove = ['iso3c', 'iso2c','adminregion']  # Replace with the names of the columns you want to remove
data_df = data_df.drop(columns=columns_to_remove, errors='ignore')
data_df
# Out:
#           country  year   population  pop_density  net_migration  \
# 0      Arab World  2018  419790588.0    37.372365            NaN
# 1      Arab World  2017  411898965.0    36.669804     -1408824.0
# 2      Arab World  2016  404024433.0    35.968764            NaN
# 3      Arab World  2015  396028278.0    35.256897            NaN
# 4      Arab World  2014  387907748.0    34.533978            NaN
# ...           ...   ...          ...          ...            ...
# 15571    Zimbabwe  1964    4322861.0    11.174515            NaN
# 15572    Zimbabwe  1963    4178726.0    10.801928            NaN
# 15573    Zimbabwe  1962    4039201.0    10.441259       -15009.0
# 15574    Zimbabwe  1961    3905034.0    10.094440            NaN
# 15575    Zimbabwe  1960    3776681.0          NaN            NaN
#
#        migration_perc               region          incomeLevel lendingType  \
# 0                 NaN           Aggregates           Aggregates  Aggregates
# ...

# %%
data_df=data_df.dropna()
data_df
# Out:
#            country  year  population  pop_density  net_migration  \
# 2774   Afghanistan  2017  36296400.0    55.595993      -314602.0
# 2779   Afghanistan  2012  31161376.0    47.730564       521769.0
# 2784   Afghanistan  2007  27100536.0    41.510486     -1046361.0
# 2789   Afghanistan  2002  22600770.0    34.618096       744193.0
# 2794   Afghanistan  1997  19357126.0    29.649735      -867540.0
# ...            ...   ...         ...          ...            ...
# 15553     Zimbabwe  1982   7958241.0    20.571904        99068.0
# 15558     Zimbabwe  1977   6712827.0    17.352532      -152283.0
# 15563     Zimbabwe  1972   5673911.0    14.666954       -45547.0
# 15568     Zimbabwe  1967   4779827.0    12.355763       -42001.0
# 15573     Zimbabwe  1962   4039201.0    10.441259       -15009.0
#
#        migration_perc               region          incomeLevel lendingType  \
# 2774        -0.008668           South Asia           Low income         IDA
# ...

# %%
top10_country=data_df.loc[
    data_df['country'].isin([
        'India', 'Mexico', 'Russian Federation', 'China', 'Bangladesh', 'Pakistan', 'Ukraine', 'Philippines', 'Poland', 'United Kingdom'
    ])]
top10_country
# Out:
#               country  year   population  pop_density  net_migration  \
# 3659       Bangladesh  2017  159670593.0  1226.631274     -1847503.0
# 3664       Bangladesh  2012  151007807.0  1160.081486     -2306839.0
# 3669       Bangladesh  2007  142660376.0  1095.954337     -3254778.0
# 3674       Bangladesh  2002  132478086.0  1017.731321     -1492537.0
# 3679       Bangladesh  1997  120160564.0   923.104894      -719899.0
# ...               ...   ...          ...          ...            ...
# 14904  United Kingdom  1982   56313641.0   232.768326       -97495.0
# 14909  United Kingdom  1977   56193492.0   232.271698        39119.0
# 14914  United Kingdom  1972   56086065.0   231.827657       106415.0
# 14919  United Kingdom  1967   54943600.0   227.105361       -84853.0
# 14924  United Kingdom  1962   53250000.0   220.104989       143068.0
#
#        migration_perc                 region          incomeLevel  \
# 3659        -0.011571             South Asia  Lower middle income
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_df.head()
# Out:
#           country  year  population  pop_density  net_migration  \
# 2774  Afghanistan  2017  36296400.0    55.595993      -314602.0
# 2779  Afghanistan  2012  31161376.0    47.730564       521769.0
# 2784  Afghanistan  2007  27100536.0    41.510486     -1046361.0
# 2789  Afghanistan  2002  22600770.0    34.618096       744193.0
# 2794  Afghanistan  1997  19357126.0    29.649735      -867540.0
#
#       migration_perc      region incomeLevel lendingType capitalCity  \
# 2774       -0.008668  South Asia  Low income         IDA       Kabul
# 2779        0.016744  South Asia  Low income         IDA       Kabul
# 2784       -0.038610  South Asia  Low income         IDA       Kabul
# 2789        0.032928  South Asia  Low income         IDA       Kabul
# 2794       -0.044818  South Asia  Low income         IDA       Kabul
#
#       longitude  latitude
# 2774    69.1761   34.5228
# 2779    69.1761   34.5228
# 2784    69.1761   34.5228
# 2789    69.1761   34.5228
# 2794    69.1761   34.5228

# %%
#vis = sns.load_dataset(data_df["year"])
plt.figure(figsize=(10,4))

sns.boxplot(top10_country, x="country", y="net_migration", hue="country")
plt.xticks(rotation=75)
plt.show()

# %%
#vis = sns.load_dataset(data_df["year"])
plt.figure(figsize=(10,4))

sns.boxplot(top10_country, x="country", y="population", hue="country")
plt.xticks(rotation=75)
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.stripplot(top10_country, x="incomeLevel", y="net_migration", hue="country")
plt.legend(loc="lower right", ncol=2) #bbox_to_anchor=(.5,1)
plt.show()

# %%
from scipy.stats import pearsonr

data_df.loc[data_df["incomeLevel"]=="Low income", 'Income_score'] = 1
data_df.loc[data_df["incomeLevel"]=="Lower middle income", 'Income_score'] = 2
data_df.loc[data_df["incomeLevel"]=="Upper middle income", 'Income_score'] = 3
data_df.loc[data_df["incomeLevel"]=="High income", 'Income_score'] = 4

net_corr, net_pval = pearsonr(data_df['Income_score'], data_df['net_migration'])
print('Net Correl: ', net_corr)
print('Net P_Val: ', net_pval)
# Out:
# Net Correl:  0.2029237047996844
# Net P_Val:  6.9162661267865745e-22
# C:\Users\brian\AppData\Local\Temp\ipykernel_26216\1544024228.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_df.loc[data_df["incomeLevel"]=="Low income", 'Income_score'] = 1

# %%
incCorr = data_df["Income_score"].corr(data_df["pop_density"])
incCorr
# Out:
# 0.15056641014688274
